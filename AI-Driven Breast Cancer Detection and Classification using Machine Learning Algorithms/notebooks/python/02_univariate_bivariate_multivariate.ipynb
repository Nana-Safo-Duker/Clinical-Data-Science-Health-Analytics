# %% [markdown]
# # Univariate, Bivariate, and Multivariate Analysis
#
# ## Breast Cancer Diagnosis Dataset
#
# This notebook contains comprehensive analysis:
# - Univariate Analysis
# - Bivariate Analysis
# - Multivariate Analysis
#
# **Note**: For detailed analysis, run the script: `scripts/python/univariate_bivariate_multivariate_analysis.py`

# %%
# Import libraries and run analysis
import subprocess
import sys

# Run the comprehensive analysis script
result = subprocess.run([sys.executable, '../../scripts/python/univariate_bivariate_multivariate_analysis.py'], 
                       capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print("Errors:", result.stderr)
