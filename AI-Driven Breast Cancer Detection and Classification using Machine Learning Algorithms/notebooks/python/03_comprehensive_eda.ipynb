# %% [markdown]
# # Comprehensive Exploratory Data Analysis (EDA)
#
# ## Breast Cancer Diagnosis Dataset
#
# This notebook provides comprehensive exploratory data analysis.
#
# **Note**: For detailed analysis, run the script: `scripts/python/comprehensive_eda.py`

# %%
# Import libraries and run analysis
import subprocess
import sys

# Run the comprehensive EDA script
result = subprocess.run([sys.executable, '../../scripts/python/comprehensive_eda.py'], 
                       capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print("Errors:", result.stderr)
