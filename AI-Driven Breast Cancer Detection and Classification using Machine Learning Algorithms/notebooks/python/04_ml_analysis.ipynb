# %% [markdown]
# # Machine Learning Analysis
#
# ## Breast Cancer Diagnosis Dataset
#
# This notebook contains machine learning analysis with multiple algorithms.
#
# **Note**: For detailed ML analysis, run the script: `scripts/python/ml_analysis.py`

# %%
# Import libraries and run analysis
import subprocess
import sys

# Run the ML analysis script
result = subprocess.run([sys.executable, '../../scripts/python/ml_analysis.py'], 
                       capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print("Errors:", result.stderr)
