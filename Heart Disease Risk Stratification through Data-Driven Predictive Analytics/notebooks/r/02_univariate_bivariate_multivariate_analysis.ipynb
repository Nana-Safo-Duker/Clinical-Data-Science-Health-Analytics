# %% [markdown]
# # Heart Disease Dataset - Univariate, Bivariate, Multivariate Analysis (R)
#
# Comprehensive univariate, bivariate, and multivariate analysis
#
# This notebook can be run cell by cell or the entire script can be executed.
#
# **Note**: For full functionality, refer to the corresponding R script in `scripts/r/`

# %%
# Load necessary libraries
library(tidyverse)
library(ggplot2)
library(corrplot)
library(Hmisc)
library(psych)
library(gridExtra)

# Load the dataset
df <- read.csv("../../data/heart-disease.csv")
cat("Dataset loaded successfully!\n")
head(df)

# %% [markdown]
# ## Running the Full Analysis
#
# The complete analysis is available in the R script. To run it:
#
# ```r
# source("../../scripts/r/univariate_bivariate_multivariate_analysis.R")
# ```
#
# Or execute the script from command line:
# ```bash
# Rscript ../../scripts/r/univariate_bivariate_multivariate_analysis.R
# ```
